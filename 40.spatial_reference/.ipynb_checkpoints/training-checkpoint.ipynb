# %%
import os
import numpy as np
import pandas as pd
import scipy as sp
import scanpy as sc

import torch
import cell2location as c2l
from cell2location.utils.filtering import filter_genes
from cell2location.models import RegressionModel
from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob

results_folder = "/projects/b1042/Gate_Lab/projects/als-project/spatial/00.ref"
barcodes_folder = "/projects/b1042/Gate_Lab/projects/als-project/spatial/03.seurat_process/barcodes"

# %%
results_folder = "/projects/b1042/Gate_Lab/projects/als-project/spatial/00.ref"
print("INFO: Started!")

ref = sc.read("/projects/b1042/Gate_Lab/projects/als-project/spatial/00.ref/ref.h5ad")
root_folder = "/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2"
search_pattern = os.path.join(root_folder, '**', 'outs')
subfolders = [path for path in glob.glob(search_pattern, recursive=True)]
# Out:
# INFO: Started!

# %%
ref.X = ref.X.astype('int')
selected = filter_genes(ref, cell_count_cutoff=5, cell_percentage_cutoff2=0.03, nonz_mean_cutoff=1.12)
ref = ref[:, selected].copy()
# set up NB regression
c2l.models.RegressionModel.setup_anndata(adata=ref,
                                         # cell type, covariate used for constructing signatures
                                         labels_key='AnnotationForDeconvolution',
                                         batch_key='sample'
                                         )

mod = RegressionModel(ref)
# view anndata_setup as a sanity check
mod.view_anndata_setup()

print("INFO: Training!")
mod.train(max_epochs=500, batch_size=2500, train_size=1, lr=0.002, use_gpu=True)
plt.close()
mod.plot_history(20)
plt.savefig(f"{results_folder}/plots/training_loss.png")
plt.close()

ref = mod.export_posterior(
    ref, sample_kwargs={'num_samples': 1000, 'batch_size': 2500, 'use_gpu': True}
)

if 'means_per_cluster_mu_fg' in ref.varm.keys():
    inf_aver = ref.varm['means_per_cluster_mu_fg'][[f'means_per_cluster_mu_fg_{i}'
                                                    for i in ref.uns['mod']['factor_names']]].copy()
else:
    inf_aver = ref.var[[f'means_per_cluster_mu_fg_{i}'
                        for i in ref.uns['mod']['factor_names']]].copy()
inf_aver.columns = ref.uns['mod']['factor_names']
ref.__dict__['_raw'].__dict__['_var'] = ref.__dict__['_raw'].__dict__['_var'].rename(columns={'_index': 'features'})
ref.write(f"{results_folder}/ref_processed.h5ad")
# Out:
# Anndata setup with scvi-tools version 1.0.0.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Setup via `RegressionModel.setup_anndata` with arguments:
# {
# │   'layer': None,
# │   'batch_key': 'sample',
# │   'labels_key': 'AnnotationForDeconvolution',
# │   'categorical_covariate_keys': None,
# │   'continuous_covariate_keys': None
# }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#          Summary Statistics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃     Summary Stat Key     ┃ Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │         n_batch          │   7   │
# │         n_cells          │ 13532 │
# │ n_extra_categorical_covs │   0   │
# │ n_extra_continuous_covs  │   0   │
# │         n_labels         │  14   │
# │          n_vars          │ 14664 │
# └──────────────────────────┴───────┘
#                Data Registry
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registry Key ┃    scvi-tools Location    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      X       │          adata.X          │
# │    batch     │ adata.obs['_scvi_batch']  │
# │    ind_x     │   adata.obs['_indices']   │
# │    labels    │ adata.obs['_scvi_labels'] │
# └──────────────┴───────────────────────────┘
#                    batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Source Location   ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['sample'] │     1      │          0          │
# │                     │     2      │          1          │
# │                     │     3      │          2          │
# │                     │     4      │          3          │
# │                     │     5      │          4          │
# │                     │     6      │          5          │
# │                     │     7      │          6          │
# └─────────────────────┴────────────┴─────────────────────┘
#                                   labels State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Source Location             ┃       Categories       ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['AnnotationForDeconvolution'] │       Astrocytes       │          0          │
# │                                         │      Endothelial       │          1          │
# │                                         │    Ependymal Cells     │          2          │
# │                                         │      Lymphocytes       │          3          │
# │                                         │      Macrophages       │          4          │
# │                                         │        Meninges        │          5          │
# │                                         │       Microglia        │          6          │
# │                                         │      MotorNeurons      │          7          │
# │                                         │        Neurons         │          8          │
# │                                         │          OPC           │          9          │
# │                                         │    Oligodendrocytes    │         10          │
# │                                         │       Pericytes        │         11          │
# │                                         │ ProliferatingMicroglia │         12          │
# │                                         │        Schwann         │         13          │
# └─────────────────────────────────────────┴────────────────────────┴─────────────────────┘
# INFO: Training!
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/pytorch/trainer/configuration_validator.py:70: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/pytorch/loops/fit_loop.py:280: PossibleUserWarning: The number of training batches (6) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 3/500:   0%|          | 2/500 [00:54<3:47:17, 27.38s/it, v_num=1, elbo_train=1.22e+8]
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/pytorch/trainer/call.py:54: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# Sampling local variables, batch:   0%|          | 0/6 [00:00<?, ?it/s]
# Sampling global variables, sample: 100%|██████████| 999/999 [10:27<00:00,  1.59it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 40
#      37 ref.__dict__['_raw'].__dict__['_var'] = ref.__dict__['_raw'].__dict__['_var'].rename(columns={'_index': 'features'})
#      38 # ref.write(f"{results_folder}/ref_processed.h5ad")
# ---> 40 all_sample_sc = sc.read_visium("/projects/b1042/Gate_Lab/projects/als-project/spatial/01.spaceranger_output/ALS_C9/outs")
#      42 # remove mitochondria-encoded (MT) genes
#      43 all_sample_sc.var['MT_gene'] = [gene.startswith('MT-') for gene in all_sample_sc.var_names]
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/scanpy/readwrite.py:360, in read_visium(path, genome, count_file, library_id, load_images, source_image_path)
#     306 """\
#     307 Read 10x-Genomics-formatted visum dataset.
#     308
#    (...)
#     357     Spatial spot coordinates, usable as `basis` by :func:`~scanpy.pl.embedding`.
#     358 """
#     359 path = Path(path)
# --> 360 adata = read_10x_h5(path / count_file, genome=genome)
#     362 adata.uns["spatial"] = dict()
#     364 from h5py import File
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/scanpy/readwrite.py:180, in read_10x_h5(filename, genome, gex_only, backup_url)
#     178 if not is_present:
#     179     logg.debug(f'... did not find original file {filename}')
# --> 180 with h5py.File(str(filename), 'r') as f:
#     181     v3 = '/matrix' in f
#     182 if v3:
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/projects/b1042/Gate_Lab/projects/als-project/spatial/01.spaceranger_output/ALS_C9/outs/filtered_feature_bc_matrix.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
subfolders
# Out:
# ['/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GBB20-16-A13-sl10___V52L18-332___C1/GBB20-16-A13-sl10___V52L18-332___C1/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-15-09-10B-sl2___V52L06-298___C4/GWF-15-09-10B-sl2___V52L06-298___C4/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/MILLERMI-N14-280-CSC___V52L18-276___D7/MILLERMI-N14-280-CSC___V52L18-276___D7/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-17-23___V52L18-276___D6/GWF-17-23___V52L18-276___D6/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/NEUUJ189PPH_SSC_2-5___V52L19-048___D5/NEUUJ189PPH_SSC_2-5___V52L19-048___D5/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/MILLERMINEUWM_344ZLM-sl10___V52L06-367___D1/MILLERMINEUWM_344ZLM-sl10___V52L06-367___D1/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GBB19-13-A13-sl5___V52L19-016___C9/GBB19-13-A13-sl5___V52L19-016___C9/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-17-24-10B-sl10___V52L18-402___B12/GWF-17-24-10B-sl10___V52L18-402___B12/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF_19-47_10___V52L19-048___D3/GWF_19-47_10___V52L19-048___D3/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-20-50-10B-sl5___V52L18-332___C2/GWF-20-50-10B-sl5___V52L18-332___C2/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/NEUDW867LF9_SCC_10-sl3___V52L19-016___C10/NEUDW867LF9_SCC_10-sl3___V52L19-016___C10/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-19-37-10B-sl10___V52L18-387___C5/GWF-19-37-10B-sl10___V52L18-387___C5/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GBB-17-21-B10-CNS-sl4___V52L19-037___D11/GBB-17-21-B10-CNS-sl4___V52L19-037___D11/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/NEULM733WR7SCC-10-sl3___V52L18-387___C6/NEULM733WR7SCC-10-sl3___V52L18-387___C6/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/MILLERMI-AU-87-sl5___V52L19-037___D12/MILLERMI-AU-87-sl5___V52L19-037___D12/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-17-24-10B-sl10___V52L19-076___B10/GWF-17-24-10B-sl10___V52L19-076___B10/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GBB21-03-A12-sl5___V52L06-340___C12/GBB21-03-A12-sl5___V52L06-340___C12/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GBB-18-01-A9-sl12___V52L06-298___C3/GBB-18-01-A9-sl12___V52L06-298___C3/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/NEUHD481VCL_SCC_19-sl14___V52L06-340___C11/NEUHD481VCL_SCC_19-sl14___V52L06-340___C11/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF-18-33-10B-sl11___V52L19-028___C7/GWF-18-33-10B-sl11___V52L19-028___C7/outs',
#  '/projects/b1042/Gate_Lab/projects/als-project/spatial/02.spaceranger_output_v2/GWF_19-35_10C-sl9___V52L06-367___D2/GWF_19-35_10C-sl9___V52L06-367___D2/outs']

# %%
for cur_folder in subfolders:
    parts = cur_folder.split('/')
    ID = parts[-2]
    print(ID)
    ID_no_dash = ID.replace("-", ".")
    # get post QC barcodes 
    cur_sample_bc_file = f"{barcodes_folder}/{ID_no_dash}.csv"
    cur_post_qc_barcodes = pd.read_csv(cur_sample_bc_file)
#     all_sample_sc = sc.read_visium(cur_folder)

#     # remove mitochondria-encoded (MT) genes
#     all_sample_sc.var['MT_gene'] = [gene.startswith('MT-') for gene in all_sample_sc.var_names]

#     # remove MT genes for spatial mapping (keeping their counts in the object)
#     all_sample_sc.obsm['MT'] = all_sample_sc[:, all_sample_sc.var['MT_gene'].values].X.toarray()
#     all_sample_sc = all_sample_sc[:, ~all_sample_sc.var['MT_gene'].values]

#     # remove hemoglobin-encoded (HB) genes
#     all_sample_sc.var['HB_gene'] = [gene.startswith('HB') for gene in all_sample_sc.var_names]

#     # remove HB genes for spatial mapping (keeping their counts in the object)
#     all_sample_sc.obsm['HB'] = all_sample_sc[:, all_sample_sc.var['HB_gene'].values].X.toarray()
#     all_sample_sc = all_sample_sc[:, ~all_sample_sc.var['HB_gene'].values]

#     all_sample_sc.X = all_sample_sc.X.astype('int')
#     shared_features = [
#         feature for feature in all_sample_sc.var_names if feature in ref.var_names
#     ]
#     print("{} genes shared!".format(str(len(shared_features))))

#     plt.savefig(f"{results_folder}/plots/filter_genes.png")
#     plt.close()


#     intersect = np.intersect1d(all_sample_sc.var_names, inf_aver.index)
#     all_sample_sc.var_names_make_unique()
#     all_sample_sc = all_sample_sc[:, intersect].copy()
#     inf_aver = inf_aver.loc[intersect, :].copy()
#     inf_aver.to_csv(f"{results_folder}/inf_aver.csv")

#     mod.plot_QC()
#     plt.savefig(f"{results_folder}/plots/training_qc.png")
#     plt.close()

#     print("INFO: Saving!")
#     # Save model
#     mod.save(f"{results_folder}/model.pt", overwrite=True)

#     sc_file = f"{results_folder}/{ID}.h5ad"
#     all_sample_sc.write(sc_file)
    break
# Out:
# GBB20-16-A13-sl10___V52L18-332___C1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 8
#       6     # get post QC barcodes
#       7     cur_sample_bc_file = f"{barcodes_folder}/{ID}.csv".replace("-", ".")
# ----> 8     cur_post_qc_barcodes = pd.read_csv(cur_sample_bc_file)
#       9 #     all_sample_sc = sc.read_visium(cur_folder)
#      10
#      11 #     # remove mitochondria-encoded (MT) genes
#    (...)
#      49 #     sc_file = f"{results_folder}/{ID}.h5ad"
#      50 #     all_sample_sc.write(sc_file)
#      51     break
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/projects/b1042/Gate_Lab/projects/als.project/spatial/03.seurat_process/barcodes/GBB20.16.A13.sl10___V52L18.332___C1.csv'

# %%
cur_sample_bc_file
# Out:
# '/projects/b1042/Gate_Lab/projects/als.project/spatial/03.seurat_process/barcodes/GBB20.16.A13.sl10___V52L18.332___C1.csv'

# %%
"/projects/b1042/Gate_Lab/projects/als-project/spatial/03.seurat_process/barcodes/GBB20.16.A13.sl10___V52L18.332___C1.csv"

# %% [markdown]
# # Archive

# %%
import scanpy as sc

# %%
ref = sc.read("/projects/b1042/Gate_Lab/projects/als-project/spatial/00.ref/ref.h5ad")

# %%
all_sample_sc = sc.read_visium("/projects/b1042/Gate_Lab/projects/als-project/spatial/01.spaceranger_output/ALS_C9/outs")
# Out:
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
# remove mitochondria-encoded (MT) genes
all_sample_sc.var['MT_gene'] = [gene.startswith('MT-') for gene in all_sample_sc.var_names]

# remove MT genes for spatial mapping (keeping their counts in the object)
all_sample_sc.obsm['MT'] = all_sample_sc[:, all_sample_sc.var['MT_gene'].values].X.toarray()
all_sample_sc = all_sample_sc[:, ~all_sample_sc.var['MT_gene'].values]

# remove hemoglobin-encoded (HB) genes
all_sample_sc.var['HB_gene'] = [gene.startswith('HB') for gene in all_sample_sc.var_names]

# remove HB genes for spatial mapping (keeping their counts in the object)
all_sample_sc.obsm['HB'] = all_sample_sc[:, all_sample_sc.var['HB_gene'].values].X.toarray()
all_sample_sc = all_sample_sc[:, ~all_sample_sc.var['HB_gene'].values]
# Out:
# /tmp/ipykernel_133213/1541179833.py:2: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   all_sample_sc.var['MT_gene'] = [gene.startswith('MT-') for gene in all_sample_sc.var_names]
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /tmp/ipykernel_133213/1541179833.py:9: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   all_sample_sc.var['HB_gene'] = [gene.startswith('HB') for gene in all_sample_sc.var_names]

# %%
all_sample_sc.X = all_sample_sc.X.astype('int')
ref.X = ref.X.astype('int')

# %%
shared_features = [
    feature for feature in all_sample_sc.var_names if feature in ref.var_names
]
print("{} genes shared!".format(str(len(shared_features))))
# Out:
# 17836 genes shared!

# %%
selected = filter_genes(ref, cell_count_cutoff=5, cell_percentage_cutoff2=0.03, nonz_mean_cutoff=1.12)
# Out:
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
ref = ref[:, selected].copy()

# %%
c2l.models.RegressionModel.setup_anndata(adata=ref,
                                         # cell type, covariate used for constructing signatures
                                         labels_key='AnnotationForDeconvolution'
                                         )
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
mod = RegressionModel(ref)
# view anndata_setup as a sanity check
mod.view_anndata_setup()
print("INFO: Training!")
mod.train(max_epochs=50, lr=0.002)
# Out:
# Anndata setup with scvi-tools version 1.0.0.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Setup via `RegressionModel.setup_anndata` with arguments:
# {
# │   'layer': None,
# │   'batch_key': None,
# │   'labels_key': 'AnnotationForDeconvolution',
# │   'categorical_covariate_keys': None,
# │   'continuous_covariate_keys': None
# }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#          Summary Statistics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃     Summary Stat Key     ┃ Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │         n_batch          │   1   │
# │         n_cells          │ 13532 │
# │ n_extra_categorical_covs │   0   │
# │ n_extra_continuous_covs  │   0   │
# │         n_labels         │  14   │
# │          n_vars          │ 14664 │
# └──────────────────────────┴───────┘
#                Data Registry
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registry Key ┃    scvi-tools Location    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      X       │          adata.X          │
# │    batch     │ adata.obs['_scvi_batch']  │
# │    ind_x     │   adata.obs['_indices']   │
# │    labels    │ adata.obs['_scvi_labels'] │
# └──────────────┴───────────────────────────┘
#                      batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_batch'] │     0      │          0          │
# └──────────────────────────┴────────────┴─────────────────────┘
#                                   labels State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Source Location             ┃       Categories       ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['AnnotationForDeconvolution'] │       Astrocytes       │          0          │
# │                                         │      Endothelial       │          1          │
# │                                         │    Ependymal Cells     │          2          │
# │                                         │      Lymphocytes       │          3          │
# │                                         │      Macrophages       │          4          │
# │                                         │        Meninges        │          5          │
# │                                         │       Microglia        │          6          │
# │                                         │      MotorNeurons      │          7          │
# │                                         │        Neurons         │          8          │
# │                                         │          OPC           │          9          │
# │                                         │    Oligodendrocytes    │         10          │
# │                                         │       Pericytes        │         11          │
# │                                         │ ProliferatingMicroglia │         12          │
# │                                         │        Schwann         │         13          │
# └─────────────────────────────────────────┴────────────────────────┴─────────────────────┘
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# INFO: Training!
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/pytorch/trainer/configuration_validator.py:70: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/pytorch/loops/fit_loop.py:280: PossibleUserWarning: The number of training batches (6) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 50/50: 100%|██████████| 50/50 [17:08<00:00, 20.21s/it, v_num=1, elbo_train=1.15e+8]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 50/50: 100%|██████████| 50/50 [17:08<00:00, 20.57s/it, v_num=1, elbo_train=1.15e+8]

# %%
mod.plot_history(20)
plt.savefig(f"{results_folder}/plots/loss_curve.png")
plt.close()

# %%
ref = mod.export_posterior(
    ref, sample_kwargs={'num_samples': 10, 'batch_size': 2500}
)
# Out:
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/lightning/fabric/plugins/environments/slurm.py:165: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/ ...
#   rank_zero_warn(
# Sampling local variables, batch:   0%|          | 0/6 [00:01<?, ?it/s]
# Sampling global variables, sample: 100%|██████████| 9/9 [00:04<00:00,  1.89it/s]

# %%
if 'means_per_cluster_mu_fg' in ref.varm.keys():
    inf_aver = ref.varm['means_per_cluster_mu_fg'][[f'means_per_cluster_mu_fg_{i}' 
                                    for i in ref.uns['mod']['factor_names']]].copy()
else:
    inf_aver = ref.var[[f'means_per_cluster_mu_fg_{i}' 
                                    for i in ref.uns['mod']['factor_names']]].copy()
inf_aver.columns = ref.uns['mod']['factor_names']
inf_aver.iloc[0:5, 0:5]
intersect = np.intersect1d(all_sample_sc.var_names, inf_aver.index)
all_sample_sc.var_names_make_unique()
all_sample_sc = all_sample_sc[:, intersect].copy()
inf_aver = inf_aver.loc[intersect, :].copy()
# Out:
# /home/zzj4347/softwares/anaconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
inf_aver.to_csv(f"{results_folder}/inf_aver.csv")

# %%
mod.plot_QC()
plt.savefig(f"{results_folder}/plots/training_qc.png")
plt.close()

# %%
ref.__dict__['_raw'].__dict__['_var'] = ref.__dict__['_raw'].__dict__['_var'].rename(columns={'_index': 'features'})
ref.write(f"{results_folder}/ref_processed.h5ad")

# %%
sc_file = f"{results_folder}/all_sample_sc_after_training.h5ad"
all_sample_sc.write(sc_file)
